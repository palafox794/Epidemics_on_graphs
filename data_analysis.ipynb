# %%
R.version
# Out:
#                _
# platform       x86_64-apple-darwin17.0
# arch           x86_64
# os             darwin17.0
# system         x86_64, darwin17.0
# status
# major          4
# minor          0.0
# year           2020
# month          04
# day            24
# svn rev        78286
# language       R
# version.string R version 4.0.0 (2020-04-24)
# nickname       Arbor Day

# %%
z <- read.csv("network_data.csv")

names(z) <- c("index", "time", "susc", "inf", "rec")

# %%
plot(z[c(2,3)], col="firebrick3", ylim=c(0, 4039), main="", 
     ylab="Cantidad de individuos", xlab="tiempo")
points(z[c(2,4)], col="darkgoldenrod3")
points(z[c(2,5)], col="darkblue")
legend(x = "right", legend = c("Susceptible", "Infeccioso", "Removido"), 
       fill = c("firebrick3", "darkgoldenrod3","darkblue"), 
       title = "")
# Out:
# Plot with title “”

# %%
png(filename="sir.png", height=2000, width=2000, res=400, bg="transparent")
plot(z[c(2,3)], col="firebrick3", ylim=c(0, 4039), main="", 
     ylab="Cantidad de individuos", xlab="tiempo")
points(z[c(2,4)], col="darkgoldenrod3")
points(z[c(2,5)], col="darkblue")
legend(x = "right", legend = c("Susceptible", "Infeccioso", "Removido"), 
       fill = c("firebrick3", "darkgoldenrod3","darkblue"), 
       title = "")
dev.off()
# Out:
# pdf
#   2
